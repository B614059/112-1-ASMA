# %% [markdown]
# # Day 2 特徵工程
# * 建議可以先「變更執行階段類型」為「TPU」或「GPU」，利於後段機器學習模型訓練

# %% [markdown]
# ## 套件

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.decomposition import PCA

# %% [markdown]
# ## 一、資料集
# * 請上傳你的資料集並更改為你的檔名

# %%
df = pd.read_csv('smiles_descriptor.csv')
df
# Out:
#      Unnamed: 0   ID             name  \
# 0             0    1  ABACAVIRSULFATE
# 1             1    2         ACARBOSE
# 2             2    3       ACEBUTOLOL
# 3             3    4       ACECAINIDE
# 4             4    5      ACECLOFENAC
# ..          ...  ...              ...
# 935         935  936       ZONISAMIDE
# 936         936  937        ZOPICLONE
# 937         937  938         ZOTEPINE
# 938         938  939         ZOTEPINE
# 939         939  940   ZUCLOPENTHIXOL
#
#                                                 smiles  output  nAcid   ALogP  \
# 0                 Nc1nc(NC2CC2)c3ncn(C4CC(CO)C=C4)c3n1       0    0.0 -1.8653
# 1    CC1OC(OC2C(O)C(O)C(OC3C(O)C(O)C(O)OC3CO)OC2CO)...       0    0.0 -7.2263
# 2             CCCC(=O)Nc1ccc(OCC(O)CNC(C)C)c(c1)C(=O)C       0    0.0 -2.1004
# 3                     CCN(CC)CCNC(=O)c1ccc(NC(=O)C)cc1       0    0.0 -0.5179
# 4                OC(=O)COC(=O)Cc1ccccc1Nc2c(Cl)cccc2Cl       0    1.0  0.5703
# ..                                                 ...     ...    ...     ...
# 935                       c1ccc2c(c1)c(no2)CS(=O)(=O)N       1    0.0 -1.0790
# 936   CN1CCN(CC1)C(=O)OC2c3c(nccn3)C(=O)N2c4ccc(cn4)Cl       1    0.0  0.3196
# 937                 CN(C)CCOC1=Cc2ccccc2Sc3c1cc(cc3)Cl       1    0.0  1.4428
# 938                 CN(C)CCOC1=Cc2cc(ccc2Sc3c1cccc3)Cl       1    0.0  1.4428
# 939   c1ccc2c(c1)/C(=C\CCN3CCN(CC3)CCO)/c4cc(ccc4S2)Cl       1    0.0  0.9664
#
#         ALogp2       AMR       apol  ...       P1s       P2s       E1s  \
# 0     3.479344   47.8891  44.044274  ...  0.862046  0.116831  0.560654
# 1    52.219412  137.7680  88.208099  ...  0.867267  0.085380  0.587220
# 2     4.411680   67.0727  55.758204  ...  0.910758  0.057143  0.494202
# 3     0.268220   52.6108  46.640239  ...  0.908190  0.048952  0.533958
# 4     0.325242   37.1534  45.496309  ...  0.637072  0.328403  0.478416
# ..         ...       ...        ...  ...       ...       ...       ...
# 935   1.164241   17.4729  26.920344  ...  0.757968  0.181602  0.562223
# 936   0.102144   52.4709  52.441481  ...  0.608756  0.298939  0.476373
# 937   2.081672   48.3903  50.664274  ...  0.761822  0.179889  0.535430
# 938   2.081672   48.3903  50.664274  ...  0.763356  0.176037  0.533508
# 939   0.933929   66.7652  63.471825  ...       NaN       NaN       NaN
#
#           E2s       E3s         Ts          As          Vs        Ks        Ds
# 0    0.379450  0.268039  20.706840   52.049186   91.644726  0.793068  1.208143
# 1    0.443947  0.472578  40.811368  198.465988  477.620358  0.800900  1.503745
# 2    0.319559  0.386393  29.370226   71.693573  143.387359  0.866137  1.200154
# 3    0.387559  0.470449  24.128665   49.765298  100.659835  0.862285  1.391967
# 4    0.401624  0.358254  15.813288   60.651906  105.027532  0.455608  1.238294
# ..        ...       ...        ...         ...         ...       ...       ...
# 935  0.458080  0.319946   9.152687   16.287467   31.817957  0.636952  1.340249
# 936  0.361331  0.438777  15.938358   67.512784  151.462539  0.413134  1.276481
# 937  0.342230  0.420814  16.442415   51.890192  103.842100  0.642733  1.298474
# 938  0.372269  0.410134  16.487995   52.009092  105.002302  0.645034  1.315910
# 939       NaN       NaN        NaN         NaN         NaN       NaN       NaN
#
# [940 rows x 1880 columns]

# %% [markdown]
# ## 刪除欄位

# %%
df = df.drop(columns=['Unnamed: 0', 'ID', 'name', 'smiles'])
df
# Out:
#      output  nAcid   ALogP     ALogp2       AMR       apol  naAromAtom  \
# 0         0    0.0 -1.8653   3.479344   47.8891  44.044274         9.0
# 1         0    0.0 -7.2263  52.219412  137.7680  88.208099         0.0
# 2         0    0.0 -2.1004   4.411680   67.0727  55.758204         6.0
# 3         0    0.0 -0.5179   0.268220   52.6108  46.640239         6.0
# 4         0    1.0  0.5703   0.325242   37.1534  45.496309        12.0
# ..      ...    ...     ...        ...       ...        ...         ...
# 935       1    0.0 -1.0790   1.164241   17.4729  26.920344         9.0
# 936       1    0.0  0.3196   0.102144   52.4709  52.441481        12.0
# 937       1    0.0  1.4428   2.081672   48.3903  50.664274        12.0
# 938       1    0.0  1.4428   2.081672   48.3903  50.664274        12.0
# 939       1    0.0  0.9664   0.933929   66.7652  63.471825        12.0
#
#      nAromBond  nAtom  nHeavyAtom  ...       P1s       P2s       E1s  \
# 0         10.0   39.0        21.0  ...  0.862046  0.116831  0.560654
# 1          0.0   87.0        44.0  ...  0.867267  0.085380  0.587220
# 2          6.0   52.0        24.0  ...  0.910758  0.057143  0.494202
# 3          6.0   43.0        20.0  ...  0.908190  0.048952  0.533958
# 4         12.0   36.0        23.0  ...  0.637072  0.328403  0.478416
# ..         ...    ...         ...  ...       ...       ...       ...
# 935       10.0   22.0        14.0  ...  0.757968  0.181602  0.562223
# 936       12.0   44.0        27.0  ...  0.608756  0.298939  0.476373
# 937       12.0   40.0        22.0  ...  0.761822  0.179889  0.535430
# 938       12.0   40.0        22.0  ...  0.763356  0.176037  0.533508
# 939       12.0   52.0        27.0  ...       NaN       NaN       NaN
#
#           E2s       E3s         Ts          As          Vs        Ks        Ds
# 0    0.379450  0.268039  20.706840   52.049186   91.644726  0.793068  1.208143
# 1    0.443947  0.472578  40.811368  198.465988  477.620358  0.800900  1.503745
# 2    0.319559  0.386393  29.370226   71.693573  143.387359  0.866137  1.200154
# 3    0.387559  0.470449  24.128665   49.765298  100.659835  0.862285  1.391967
# 4    0.401624  0.358254  15.813288   60.651906  105.027532  0.455608  1.238294
# ..        ...       ...        ...         ...         ...       ...       ...
# 935  0.458080  0.319946   9.152687   16.287467   31.817957  0.636952  1.340249
# 936  0.361331  0.438777  15.938358   67.512784  151.462539  0.413134  1.276481
# 937  0.342230  0.420814  16.442415   51.890192  103.842100  0.642733  1.298474
# 938  0.372269  0.410134  16.487995   52.009092  105.002302  0.645034  1.315910
# 939       NaN       NaN        NaN         NaN         NaN       NaN       NaN
#
# [940 rows x 1876 columns]

# %% [markdown]
# ## 填補資料/刪除資料
# * 請同學直接使用上週填補資料的結果
# * 本範例直接刪除空值的資料（浪費！）

# %%
df = df.dropna()
df.describe()
# Out:
#            output       nAcid       ALogP        ALogp2         AMR  \
# count  751.000000  751.000000  751.000000  7.510000e+02  751.000000
# mean     0.366178    0.230360   -0.539519  2.299822e+00   49.346474
# std      0.482080    0.580974    1.418245  5.951057e+00   25.441180
# min      0.000000    0.000000   -9.309100  4.900000e-07    7.219300
# 25%      0.000000    0.000000   -1.370450  1.917564e-01   33.359550
# 50%      0.000000    0.000000   -0.499200  8.202925e-01   45.020600
# 75%      1.000000    0.000000    0.317700  2.338766e+00   59.688350
# max      1.000000    4.000000    5.546300  8.665934e+01  207.953800
#
#              apol  naAromAtom   nAromBond       nAtom  nHeavyAtom  ...  \
# count  751.000000  751.000000  751.000000  751.000000  751.000000  ...
# mean    47.325800    8.061252    8.306258   41.129161   21.687084  ...
# std     16.596114    5.080838    5.335361   15.419662    7.082322  ...
# min      8.231172    0.000000    0.000000    9.000000    4.000000  ...
# 25%     35.876516    6.000000    6.000000   31.000000   17.000000  ...
# 50%     47.124274    6.000000    6.000000   40.000000   22.000000  ...
# 75%     57.335393   12.000000   12.000000   50.000000   26.000000  ...
# max    133.058717   24.000000   25.000000  127.000000   58.000000  ...
#
#               P1s         P2s         E1s         E2s         E3s          Ts  \
# count  751.000000  751.000000  751.000000  751.000000  751.000000  751.000000
# mean     0.705189    0.216567    0.539400    0.439521    0.394642   16.085722
# std      0.179694    0.093313    0.365608    0.073777    0.236463    9.396528
# min     -3.013569   -0.210215    0.358231    0.009991    0.077354   -2.422319
# 25%      0.624560    0.144478    0.484895    0.385797    0.339038   11.472049
# 50%      0.723406    0.204817    0.521226    0.440827    0.391216   14.427596
# 75%      0.797753    0.287841    0.562092    0.490409    0.432629   18.521415
# max      1.635949    0.455518   10.124937    0.839105    5.436597  178.093767
#
#                As           Vs          Ks          Ds
# count  751.000000   751.000000  751.000000  751.000000
# mean    55.226960   118.195488    0.579452    1.373563
# std     47.704896   123.727695    0.247612    0.573797
# min    -72.221189   -83.777196    0.130583    0.945274
# 25%     29.034550    54.435145    0.445077    1.264526
# 50%     45.378765    92.672946    0.585831    1.342676
# 75%     67.571315   143.003891    0.697315    1.420549
# max    551.567752  1634.182056    5.599021   15.571526
#
# [8 rows x 1876 columns]

# %% [markdown]
# #本範例以下步驟變更前請在此重置變數
# * df 原始資料
# * data 特徵改變後的資料（隨步驟變化）
#     * 只有特徵，沒有標註(output)
# * selected_features 目前的特徵（特徵選擇後會減少）

# %%
data = df
data = data.drop(columns=['output'])
selected_features = data.columns

# %% [markdown]
# ## 二、特徵縮放
# * 建議使用特徵縮放的方法
#     * 基於距離的演算法：例如kNN、k-Means clustering、SVM、PCA等
# * 以下兩種方法擇一即可

# %% [markdown]
# ### 2.1 標準化 Standardization (Z-score Normalization)
# #### 將特徵轉為常態分佈的z值（M=0, SD=1）
# * 適合用於
#     * 假設資料為常態分佈的演算法：例如線性回歸
#     * 假設資料中心為０的演算法：例如PCA

# %%
#標準化 Standardization (Z-score Normalization)
scaler = StandardScaler()
data = scaler.fit_transform(data)

pd.DataFrame(data).describe()
# Out:
#                0             1             2             3             4     \
# count  7.510000e+02  7.510000e+02  7.510000e+02  7.510000e+02  7.510000e+02
# mean   5.676773e-17 -1.182661e-17  3.311451e-17  2.696467e-16  5.014483e-16
# std    1.000666e+00  1.000666e+00  1.000666e+00  1.000666e+00  1.000666e+00
# min   -3.967702e-01 -6.187523e+00 -3.867135e-01 -1.656969e+00 -2.357219e+00
# 25%   -3.967702e-01 -5.862773e-01 -3.544699e-01 -6.288065e-01 -6.903371e-01
# 50%   -3.967702e-01  2.844758e-02 -2.487819e-01 -1.701476e-01 -1.215104e-02
# 75%   -3.967702e-01  6.048249e-01  6.548466e-03  4.067724e-01  6.035307e-01
# max    6.492812e+00  4.293950e+00  1.418500e+01  6.238430e+00  5.169286e+00
#
#                5             6             7             8             9     \
# count  7.510000e+02  7.510000e+02  7.510000e+02  7.510000e+02  7.510000e+02
# mean  -1.324580e-16  3.074919e-17 -4.730644e-18 -1.892258e-16  1.466500e-16
# std    1.000666e+00  1.000666e+00  1.000666e+00  1.000666e+00  1.000666e+00
# min   -1.587656e+00 -1.557869e+00 -2.085038e+00 -2.499021e+00 -2.103749e+00
# 25%   -4.059617e-01 -4.325471e-01 -6.573368e-01 -6.622415e-01 -6.970714e-01
# 50%   -4.059617e-01 -4.325471e-01 -7.327746e-02  4.421215e-02 -4.783541e-02
# 75%    7.757330e-01  6.927747e-01  5.756774e-01  6.093751e-01  6.014006e-01
# max    3.139122e+00  3.130972e+00  5.572630e+00  5.130678e+00  5.687082e+00
#
#        ...          1865          1866          1867          1868  \
# count  ...  7.510000e+02  7.510000e+02  7.510000e+02  7.510000e+02
# mean   ... -5.203708e-16 -2.743774e-16  1.726685e-16  2.223403e-16
# std    ...  1.000666e+00  1.000666e+00  1.000666e+00  1.000666e+00
# min    ... -2.070869e+01 -4.576690e+00 -4.958576e-01 -5.825852e+00
# 25%    ... -4.490017e-01 -7.730676e-01 -1.491797e-01 -7.286700e-01
# 50%    ...  1.014431e-01 -1.260053e-01 -4.974015e-02  1.771573e-02
# 75%    ...  5.154618e-01  7.643252e-01  6.210950e-02  6.902202e-01
# max    ...  5.183129e+00  2.562445e+00  2.623556e+01  5.419707e+00
#
#                1869          1870          1871          1872          1873  \
# count  7.510000e+02  7.510000e+02  7.510000e+02  7.510000e+02  7.510000e+02
# mean  -2.507241e-16 -1.892258e-17  3.784515e-17 -4.730644e-17  1.466500e-16
# std    1.000666e+00  1.000666e+00  1.000666e+00  1.000666e+00  1.000666e+00
# min   -1.342706e+00 -1.970981e+00 -2.673375e+00 -1.633485e+00 -1.814003e+00
# 25%   -2.353082e-01 -4.913249e-01 -5.494167e-01 -5.156714e-01 -5.430453e-01
# 50%   -1.449960e-02 -1.765792e-01 -2.065775e-01 -2.064174e-01  2.578098e-02
# 75%    1.607511e-01  2.593847e-01  2.589374e-01  2.006417e-01  4.763175e-01
# max    2.133660e+01  1.725276e+01  1.041133e+01  1.226077e+01  2.028546e+01
#
#                1874
# count  7.510000e+02
# mean   1.159008e-16
# std    1.000666e+00
# min   -7.469087e-01
# 25%   -1.901536e-01
# 50%   -5.386497e-02
# 75%    8.194181e-02
# max    2.476039e+01
#
# [8 rows x 1875 columns]

# %% [markdown]
# ### 2.2 最大最小縮放 Min-Max Scaling
# #### 將特徵縮放到 [0, 1] 之間
# * 適合用於不限制常態分佈的演算法

# %%
#最大最小縮放 Min-Max Scaling
scaler = MinMaxScaler()
data = scaler.fit_transform(data)

pd.DataFrame(data).describe()
# Out:
#              0           1           2           3           4           5     \
# count  751.000000  751.000000  751.000000  751.000000  751.000000  751.000000
# mean     0.057590    0.590330    0.026539    0.209865    0.313189    0.335885
# std      0.145243    0.095470    0.068672    0.126740    0.132952    0.211702
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.534395    0.002213    0.130223    0.221468    0.250000
# 50%      0.000000    0.593044    0.009466    0.188315    0.311575    0.250000
# 75%      0.000000    0.648034    0.026988    0.261385    0.393376    0.500000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#              6           7           8           9     ...        1865  \
# count  751.000000  751.000000  751.000000  751.000000  ...  751.000000
# mean     0.332250    0.272281    0.327539    0.270029  ...    0.799816
# std      0.213414    0.130675    0.131154    0.128442  ...    0.038648
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      0.240000    0.186441    0.240741    0.180556  ...    0.782474
# 50%      0.240000    0.262712    0.333333    0.263889  ...    0.803734
# 75%      0.480000    0.347458    0.407407    0.347222  ...    0.819724
# max      1.000000    1.000000    1.000000    1.000000  ...    1.000000
#
#              1866        1867        1868        1869        1870        1871  \
# count  751.000000  751.000000  751.000000  751.000000  751.000000  751.000000
# mean     0.641071    0.018550    0.518058    0.059204    0.102528    0.204313
# std      0.140166    0.037434    0.088983    0.044122    0.052054    0.076476
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.532785    0.012969    0.453262    0.048829    0.076970    0.162324
# 50%      0.623421    0.016689    0.519633    0.058565    0.093343    0.188525
# 75%      0.748132    0.020873    0.579435    0.066292    0.116021    0.224102
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#              1872        1873        1874
# count  751.000000  751.000000  751.000000
# mean     0.117565    0.082084    0.029282
# std      0.072020    0.045280    0.039231
# min      0.000000    0.000000    0.000000
# 25%      0.080451    0.057511    0.021827
# 50%      0.102709    0.083250    0.027170
# 75%      0.132006    0.103637    0.032495
# max      1.000000    1.000000    1.000000
#
# [8 rows x 1875 columns]

# %% [markdown]
# ## 三、特徵選擇

# %% [markdown]
# ### 3.1 相關係數法
#
# #### 假設：與標註低相關的特徵對模型可能幫助不大
# * 本範例請設定適合的相關係數閾值 r_threshold
#     * 提醒：重新執行前記得先重置變數才不會出錯
# * 本範例使用pandas的相關係數計算，而非sklearn
#
# #### 挑戰：相關係數閾值應該設定多少？

# %%
data = pd.DataFrame(data, columns=selected_features)

#相關分析（只看與output相關的部分）
correlations = data.corrwith(df['output'])

#特徵選擇
r_threshold = 0.04  #請選擇適當的閾值
selected_features = correlations[correlations.abs() > r_threshold].index
data = df[selected_features]

print(selected_features)
pd.DataFrame({'Feature':selected_features, 'Coorelation':data.corrwith(df['output'])})
# Out:
# Index(['nHeavyAtom', 'nN', 'nS', 'nF', 'nX', 'ATS1m', 'ATS2m', 'ATS3m',
#        'ATS0s', 'ATS1s',
#        ...
#        'Ae', 'Ve', 'L3p', 'Ap', 'L3i', 'Ai', 'Vi', 'L3s', 'As', 'Vs'],
#       dtype='object', length=652)
#                Feature  Coorelation
# nHeavyAtom  nHeavyAtom    -0.127680
# nN                  nN    -0.058472
# nS                  nS    -0.094818
# nF                  nF    -0.044834
# nX                  nX    -0.018653
# ...                ...          ...
# Ai                  Ai    -0.136919
# Vi                  Vi    -0.126322
# L3s                L3s     0.062389
# As                  As    -0.134287
# Vs                  Vs    -0.125839
#
# [652 rows x 2 columns]

# %% [markdown]
# ### 3.2 決策樹法
# #### 利用建立決策樹時的Gini不純度指標的總減少量代表特徵重要性
# * 決策樹對於資料單位較不敏感，不一定需要特徵縮放

# %%
#建立決策樹
tree = DecisionTreeClassifier()
tree.fit(data, df['output'])

importances = pd.DataFrame({'features':selected_features, 'importance':tree.feature_importances_}).sort_values('importance', ascending=False)
importances.head(10)
# Out:
#      features  importance
# 380   maxaaCH    0.176607
# 135    GATS1s    0.067037
# 328      SHBd    0.059776
# 629    RDF70s    0.034558
# 33     AATS4e    0.032018
# 194  BCUTw-1l    0.028130
# 332    SHdsCH    0.027815
# 580     TDB8r    0.023857
# 495      JGI5    0.022217
# 112    MATS5p    0.021659

# %%
from sklearn.tree import DecisionTreeClassifier
import pandas as pd

# Assuming 'data' is your standardized data as a NumPy array
tree = DecisionTreeClassifier()
tree.fit(data, df['output'])
# Get feature importances and create a DataFrame
importances = pd.DataFrame({'features': selected_features, 'importance': tree.feature_importances_})
# Sort the DataFrame by importance in descending order
importances = importances.sort_values(by='importance', ascending=False)
# Display the top 10 most important features
top_10_features = importances.head(10)

# %%
#從決策樹的信息熵來選擇
sfm = SelectFromModel(tree, threshold=.05)
data = sfm.fit_transform(data, df['output'])
data
# Out:
# array([[1.03847644, 1.46140883, 1.78335884],
#        [1.16792238, 5.05887382, 0.        ],
#        [0.72169127, 1.13230565, 1.68857271],
#        ...,
#        [0.53419835, 0.        , 1.91874274],
#        [1.00671658, 0.        , 2.71739544],
#        [1.00671658, 0.        , 2.72215238]])

# %% [markdown]
# ## 四、特徵縮減

# %% [markdown]
# ### 主成分分析 Principal Components Analysis (PCA)

# %%
#創建主成份分析
#請指定主成分個數（須小於特徵數量）
com_number = 3
pca = PCA(n_components=com_number)

pca_result = pca.fit_transform(data)
pca_result
# Out:
# array([[ 0.30888539,  0.71657248,  0.16042483],
#        [ 3.91302875,  2.47976457, -0.04003395],
#        [ 0.17133982,  0.36736584, -0.116671  ],
#        ...,
#        [-0.70627964, -0.40380981, -0.18961007],
#        [-1.32072042,  0.12977276,  0.25634034],
#        [-1.324496  ,  0.13266302,  0.25619925]])

# %%
explained_variance = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)
print("Explained variance ratio:", explained_variance)
print("Cumulative variance ratio:", cumulative_variance)
# Out:
# Explained variance ratio: [0.65866237 0.31068764 0.03064999]
# Cumulative variance ratio: [0.65866237 0.96935001 1.        ]

# %%
import matplotlib.pyplot as plt

plt.plot(range(com_number), cumulative_variance)

plt.title('Cumulative Explained Variance')
plt.xlabel('Components')
plt.ylabel('Variance')
plt.ylim(0, 1)
plt.xticks(range(com_number), range(1, com_number+1))
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a scatter plot of the PCA results
plt.scatter(pca_result[:, 0], pca_result[:, 1])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Result')
plt.show()

# %% [markdown]
# # 分類模型

# %% [markdown]
# ## 支持向量機 Support Vector Machine (SVM)

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### 使用原始資料

# %%
#分割訓練集與測試集：使用data（不降維）
x_train, x_test, y_train, y_test = train_test_split(data, df['output'], test_size=0.2245, random_state=42)
print('資料量:', x_train.shape, x_test.shape, y_train.size, y_test.size)

#創建Support Vector Classifier
model = svm.SVC(kernel='rbf', C=3000)

#模型訓練
model.fit(x_train, y_train)

#預測資料
y_pred = model.predict(x_test)

#評估模型
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 資料量: (582, 3) (169, 3) 582 169
# 0.8165680473372781

# %%
#分割訓練集與測試集：使用pca_result
x_train, x_test, y_train, y_test = train_test_split(pca_result, df['output'], test_size=0.2245, random_state=42)
print('資料量:', x_train.shape, x_test.shape, y_train.size, y_test.size)

#創建Support Vector Classifier
model = svm.SVC(kernel='rbf', C=60)

#模型訓練
model.fit(x_train, y_train)

#預測資料
y_pred = model.predict(x_test)

#評估模型
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 資料量: (582, 3) (169, 3) 582 169
# 0.834319526627219
